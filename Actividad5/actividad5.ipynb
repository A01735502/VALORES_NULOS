# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##carga de archivpo 
df=pd.read_csv('Conpenhagen_limpio.csv')

# %%
#verificacion informacion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21722 entries, 0 to 21721
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      21722 non-null  int64
#  1   name                            21722 non-null  object
#  2   last_scraped                    21722 non-null  object
#  3   description                     21722 non-null  object
#  4   neighborhood_overview           21722 non-null  object
#  5   host_id                         21722 non-null  int64
#  6   host_response_time              21722 non-null  object
#  7   host_acceptance_rate            21722 non-null  object
#  8   host_is_superhost               21722 non-null  object
#  9   host_verifications              21722 non-null  object
#  10  host_has_profile_pic            21722 non-null  object
#  11  host_identity_verified          21722 non-null  object
# ...

# %%
##impresion 5 registros

df.head(5)
# Out:
#    Unnamed: 0                                               name last_scraped  \
# 0           0  Beautiful, spacious, central, renovated Penthouse   24/03/2025
# 1           1  155 m2 artist flat on Vesterbro, with 2 bathrooms   24/03/2025
# 2           2                Cozy flat for Adults/Quiet for kids   24/03/2025
# 3           3                     0 min. from everything in Cph.   24/03/2025
# 4           4            Stylish apartment in central Copenhagen   24/03/2025
#
#                                          description  \
# 0  Welcome to our home, we hope you will enjoy Wo...
# 1  You enter a narrow entrance and feel the good ...
# 2  Our flat is placed in a Central AND Quiet neig...
# 3  It doesn't get more central than this. Histori...
# 4  Big, bright, airy and attractive apartment dec...
#
#                                neighborhood_overview  host_id  \
# 0  What else is nearby?<br />To be honest, We thi...   129976
# ...

# %%
# 1. name
Tabla_freq1 = df['name'].value_counts().reset_index()
Tabla_freq1
F1_index1 = Tabla_freq1.set_index('name')
F1_index1
# Out:
#                                        count
# name
# Hyggelig lejlighed på Nørrebro            65
# Lejlighed i København                     60
# Cozy apartment in Copenhagen              50
# Hyggelig lejlighed på Østerbro            32
# Lejlighed i hjertet af København          26
# ...                                      ...
# Nordic Loft Christianshavn                 1
# Unique house in "Kartoffelrækkerne"        1
# Nordic city atmosphere in green oasis      1
# Cosy 3 room apt. with roof terrace         1
# Extraordinary Apartment                    1
#
# [19522 rows x 1 columns]

# %%
# 2. host_response_time
Tabla_freq2 = df['host_response_time'].value_counts().reset_index()
Tabla_freq2
F1_index2 = Tabla_freq2.set_index('host_response_time')
F1_index2
# Out:
#                            count
# host_response_time
# within a few days or more  18890
# within a few hours          2832

# %%
# 3. host_acceptance_rate
Tabla_freq3 = df['host_acceptance_rate'].value_counts().reset_index()
Tabla_freq3
F1_index3 = Tabla_freq3.set_index('host_acceptance_rate')
F1_index3
# Out:
#                       count
# host_acceptance_rate
# 0                      4757
# 100%                   4755
# 0%                     1252
# 50%                     838
# 67%                     580
# ...                     ...
# 3%                       14
# 49%                      12
# 100                       8
# 2%                        8
# 1%                        1
#
# [103 rows x 1 columns]

# %%
# 4. host_is_superhost
Tabla_freq4 = df['host_is_superhost'].value_counts().reset_index()
Tabla_freq4
F1_index4 = Tabla_freq4.set_index('host_is_superhost')
F1_index4
# Out:
#                    count
# host_is_superhost
# f                  18890
# t                   2832

# %%
# 5. host_verifications
Tabla_freq5 = df['host_verifications'].value_counts().reset_index()
Tabla_freq5
F1_index5 = Tabla_freq5.set_index('host_verifications')
F1_index5
# Out:
#                                   count
# host_verifications
# ['email', 'phone']                17638
# ['phone']                          2331
# ['email', 'phone', 'work_email']   1644
# ['phone', 'work_email']              73
# ['email']                            16
# []                                    9
# ['email', 'work_email']               6
# no tiene verificación                 5

# %%
# 6. neighbourhood
Tabla_freq6 = df['neighbourhood'].value_counts().reset_index()
Tabla_freq6
F1_index6 = Tabla_freq6.set_index('neighbourhood')
F1_index6
# Out:
#                                                 count
# neighbourhood
# Denmark, Copenhagen                             13326
# Copenhagen, Denmark                              6566
# Frederiksberg, Denmark                            755
# Copenhagen, Capital Region of Denmark, Denmark    429
# Copenhagen, Hovedstaden, Denmark                   67
# ...                                               ...
# Copenhagen,  Copenhagen V, Denmark                  1
#  Copenhagen SV, Denmark                             1
# Valby, Copenhagen, Denmark                          1
# Copenhagen, København , Denmark                     1
# Copenhagen, Copenhagen, Sjælland, Denmark           1
#
# [215 rows x 1 columns]

# %%
# 7. room_type
Tabla_freq7 = df['room_type'].value_counts().reset_index()
Tabla_freq7
F1_index7 = Tabla_freq7.set_index('room_type')
F1_index7
# Out:
#                  count
# room_type
# Entire home/apt  19829
# Private room      1878
# Shared room         11
# Hotel room           4

# %%
# 8. amenities
Tabla_freq8 = df['amenities'].value_counts().reset_index()
Tabla_freq8
F1_index8 = Tabla_freq8.set_index('amenities')
F1_index8
# Out:
#                                                     count
# amenities
# ["Smoke alarm", "Kitchen", "Wifi", "TV", "Washe...     56
# ["TV", "Kitchen", "Washer", "Wifi"]                    52
# ["Kitchen", "Wifi", "TV", "Washer", "Paid parki...     50
# ["Smoke alarm", "Kitchen", "Wifi", "TV", "Washer"]     43
# ["Smoke alarm", "Outdoor dining area", "Kitchen...     35
# ...                                                   ...
# ["Essentials", "Smoke alarm", "Dishwasher", "Be...      1
# ["Essentials", "Smoke alarm", "Dishwasher", "Be...      1
# ["Free parking on premises", "Heating", "BBQ gr...      1
# ["Heating", "Smoke alarm", "First aid kit", "Sh...      1
# ["Essentials", "Room-darkening shades", "Smoke ...      1
#
# [20379 rows x 1 columns]

# %%
# 9. license
Tabla_freq9 = df['license'].value_counts().reset_index()
Tabla_freq9
F1_index9 = Tabla_freq9.set_index('license')
F1_index9
# Out:
#                    count
# license
# No tiene licencia  21722

# %%
# 10. instant_bookable
Tabla_freq10 = df['instant_bookable'].value_counts().reset_index()
Tabla_freq10
F1_index10 = Tabla_freq10.set_index('instant_bookable')
F1_index10
# Out:
#                   count
# instant_bookable
# f                 19655
# t                  2067

# %%
F1_index1.head(10).plot(kind='bar', width=0.8, figsize=(10,4), color="violet")
plt.title('Frecuencia de Nombres')
plt.xlabel('Nombres')
plt.xticks(rotation=90)
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 2. host_response_time - area
F1_index2.plot(kind='area', figsize=(10,4), alpha=1)
plt.title('Distribución Host Response Time')
plt.xlabel('Tipo de Respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 3. host_acceptance_rate Pastel
F1_index3_porcentajes = F1_index3[F1_index3.index.str.contains('%', na=False)]
F1_index3["count"].head(15).plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Host Acceptance Rate')
# Out:
# Text(0.5, 1.0, 'Host Acceptance Rate')

# %%
##host is super host 
F1_index4.plot(kind='bar', width=0.8, figsize=(10,4), color="cyan")
plt.title('Frecuencia de Superhosts')
plt.xlabel('Superhost')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 5. host_verifications
F1_index5.plot(kind='bar', figsize=(10,4), alpha=1)
plt.title('Frecuencia de Verificaciones')
plt.xlabel('Tipo de Verificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 6. neighbourhood
F1_index6["count"].head(5).plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Frecuencia por Neighbourhood')
# Out:
# Text(0.5, 1.0, 'Frecuencia por Neighbourhood')

# %%
# 7. room_type
F1_index7.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Frecuencia por Room Type')
plt.xlabel('Room Type')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 8. amenities 
F1_index8.head(10).plot(kind='bar', figsize=(10,4), alpha=1)
plt.title('Distribución de Amenities')
plt.xlabel('Amenidades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 9. license 
F1_index9["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Frecuencia de License')
# Out:
# Text(0.5, 1.0, 'Frecuencia de License')

# %%
# 10. instant_bookable 
F1_index10.plot(kind='bar', width=0.8, figsize=(10,4), color="skyblue")
plt.title('Frecuencia de Instant Bookable')
plt.xlabel('Disponibilidad Instantánea')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# DETERMINACION DE CLASES PARA DATOS AGRUPADOS

# %%
##Ajustar filas al max

pd.set_option('display.max_rows', None)

# %%
##corroboramos valore nulos 
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                        0
# name                              0
# last_scraped                      0
# description                       0
# neighborhood_overview             0
# host_id                           0
# host_response_time                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_verifications                0
# host_has_profile_pic              0
# host_identity_verified            0
# neighbourhood                     0
# room_type                         0
# amenities                         0
# first_review                      0
# last_review                       0
# license                           0
# instant_bookable                  0
# host_response_rate                0
# host_listings_count               0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# ...

# %%
# 1. estimated_revenue_l365d

df['estimated_revenue_l365d'].info()  
n=21722

# 2. host_acceptance_rate
df['review_scores_value'].info()  


# 3. calculated_host_listings_count
df['calculated_host_listings_count'].info()  # n=21722

# 4. accommodates
df['accommodates'].info()  # n=21722

# 5. bathrooms
df['bathrooms'].info()  # n=21722

# 6. beds
df['beds'].info()  # n=21722

# 7. price
df['price'].info()  # n=21722

# 8. maximum_nights_avg_ntm
df['maximum_nights_avg_ntm'].info()  # n=21722

# 9. availability_365
df['availability_365'].info()  # n=21722

# 10. number_of_reviews
df['number_of_reviews'].info()  # n=21722
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21722 entries, 0 to 21721
# Series name: estimated_revenue_l365d
# Non-Null Count  Dtype
# --------------  -----
# 21722 non-null  float64
# dtypes: float64(1)
# memory usage: 169.8 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 21722 entries, 0 to 21721
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 21722 non-null  float64
# dtypes: float64(1)
# memory usage: 169.8 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 21722 entries, 0 to 21721
# Series name: calculated_host_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 21722 non-null  float64
# dtypes: float64(1)
# memory usage: 169.8 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 21722 entries, 0 to 21721
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 21722 non-null  float64
# dtypes: float64(1)
# memory usage: 169.8 KB
# <class 'pandas.core.series.Series'>
# ...

# %%
# 1. host_response_rate
Max1 = df['estimated_revenue_l365d'].max()
Min1 = df['estimated_revenue_l365d'].min()
Limites1 = [Max1, Min1]
Limites1

# 2. host_acceptance_rate
Max2 = df['review_scores_value'].max()
Min2 = df['review_scores_value'].min()
Limites2 = [Max2, Min2]
Limites2

# 3. calculated_host_listings_count
Max3 = df['calculated_host_listings_count'].max()
Min3 = df['calculated_host_listings_count'].min()
Limites3 = [Max3, Min3]
Limites3

# 4. accommodates
Max4 = df['accommodates'].max()
Min4 = df['accommodates'].min()
Limites4 = [Max4, Min4]
Limites4

# 5. bathrooms
Max5 = df['bathrooms'].max()
Min5 = df['bathrooms'].min()
Limites5 = [Max5, Min5]
Limites5

# 6. beds
Max6 = df['beds'].max()
Min6 = df['beds'].min()
Limites6 = [Max6, Min6]
Limites6

# 7. price
Max7 = df['price'].max()
Min7 = df['price'].min()
Limites7 = [Max7, Min7]
Limites7

# 8. maximum_nights_avg_ntm
Max8 = df['maximum_nights_avg_ntm'].max()
Min8 = df['maximum_nights_avg_ntm'].min()
Limites8 = [Max8, Min8]
Limites8

# 9. availability_365
Max9 = df['availability_365'].max()
Min9 = df['availability_365'].min()
Limites9 = [Max9, Min9]
Limites9

# 10. number_of_reviews
Max10 = df['number_of_reviews'].max()
Min10 = df['number_of_reviews'].min()
Limites10 = [Max10, Min10]
Limites10
# Out:
# [np.float64(152.0), np.float64(0.0)]

# %%
# 1. estimated_revenue_l365d
R1 = Max1 - Min1
R1

# 2. review_scores_value
R2 = Max2 - Min2
R2

# 3. calculated_host_listings_count
R3 = Max3 - Min3
R3

# 4. accommodates
R4 = Max4 - Min4
R4

# 5. bathrooms
R5 = Max5 - Min5
R5

# 6. beds
R6 = Max6 - Min6
R6

# 7. price
R7 = Max7 - Min7
R7

# 8. maximum_nights_avg_ntm
R8 = Max8 - Min8
R8

# 9. availability_365
R9 = Max9 - Min9
R9

# 10. number_of_reviews
R10 = Max10 - Min10
R10
# Out:
# np.float64(152.0)

# %%
##calculamos el numero de intervales "ni", aplicando la regla de Sturges
ni=1+3.32*np.log10(n)
ni
# Out:
# np.float64(15.398507367073652)

# %%
##calculamos el ancho del intervalo "i" 
i1=R1/ni
i1

i2=R2/ni
i2

i3=R3/ni
i3

i4=R4/ni
i4

i5=R5/ni
i5

i6=R6/ni
i6   

i7=R7/ni
i7  

i8=R8/ni
i8 

i9=R9/ni
i9

i10=R10/ni
i10
# Out:
# np.float64(9.871086617461302)

# %%
##intervalo 1

intervalo1 = np.linspace(Min1, Max1,15)

##intervalo 2 

intervalo2=np.linspace(Min2+0.001, Max2+0.002,15)
intervalo2

##intervalo 3
intervalo3=np.linspace(Min3+0.001, Max3+0.002,15)
intervalo3

##intervalo 4
intervalo4=np.linspace(Min4+0.001, Max4+0.002,15)
intervalo4

#intervalo 5 
intervalo5=np.linspace(Min5+0.001, Max5+0.002,15)
intervalo5

##intervalo 6 
intervalo6=np.linspace(Min6+0.001, Max6+0.002,15)
intervalo6

##intervalo 7
intervalo7=np.linspace(Min7+0.001, Max7+0.002,15)
intervalo7

##intervalo 8
intervalo8=np.linspace(Min8+0.001, Max8+0.002,15)
intervalo8

##intervalo 9
intervalo9=np.linspace(Min9+0.001, Max9+0.002,15)
intervalo9  

##intervalo 10
intervalo10=np.linspace(Min10+0.001, Max10+0.002,15)
intervalo10
# Out:
# array([1.00000000e-03, 1.08582143e+01, 2.17154286e+01, 3.25726429e+01,
#        4.34298571e+01, 5.42870714e+01, 6.51442857e+01, 7.60015000e+01,
#        8.68587143e+01, 9.77159286e+01, 1.08573143e+02, 1.19430357e+02,
#        1.30287571e+02, 1.41144786e+02, 1.52002000e+02])

# %%
categorias=["categoria1","categoria2","categoria3","categoria4","categoria5","categoria6","categoria7","categoria8","categoria9","categoria10","categoria11","categoria12","categoria13","categoria14"]

# %%
# 1. estimated_revenue_l365d
df['estimated_revenue_l365d_cat'] = pd.cut(df['estimated_revenue_l365d'], bins=intervalo1, labels=categorias)
df[['estimated_revenue_l365d_cat']]

# 2. review_scores_value
df['review_scores_value_cat'] = pd.cut(df['review_scores_value'], bins=intervalo2, labels=catregorias)
df[['review_scores_value_cat']]

# 3. calculated_host_listings_count
df['calculated_host_listings_count_cat'] = pd.cut(df['calculated_host_listings_count'], bins=intervalo3, labels=catregorias)
df[['calculated_host_listings_count_cat']]

# 4. accommodates
df['accommodates_cat'] = pd.cut(df['accommodates'], bins=intervalo4, labels=catregorias)
df[['accommodates_cat']]

# 5. bathrooms
df['bathrooms_cat'] = pd.cut(df['bathrooms'], bins=intervalo5, labels=catregorias)
df[['bathrooms_cat']]

# 6. beds
df['beds_cat'] = pd.cut(df['beds'], bins=intervalo6, labels=catregorias)
df[['beds_cat']]

# 7. price
df['price_cat'] = pd.cut(df['price'], bins=intervalo7, labels=catregorias)
df[['price_cat']]

# 8. maximum_nights_avg_ntm
df['maximum_nights_avg_ntm_cat'] = pd.cut(df['maximum_nights_avg_ntm'], bins=intervalo8, labels=catregorias)
df[['maximum_nights_avg_ntm_cat']]

# 9. availability_365
df['availability_365_cat'] = pd.cut(df['availability_365'], bins=intervalo9, labels=catregorias)
df[['availability_365_cat']]

# 10. number_of_reviews
df['number_of_reviews_cat'] = pd.cut(df['number_of_reviews'], bins=intervalo10, labels=catregorias)
df[['number_of_reviews_cat']]
# Out:
#       number_of_reviews_cat
# 0                categoria2
# 1                categoria8
# 2                categoria1
# 3                categoria4
# 4               categoria11
# 5               categoria12
# 6                categoria1
# 7                categoria7
# 8                categoria2
# 9                categoria1
# 10               categoria2
# 11               categoria3
# 12               categoria2
# 13               categoria7
# 14               categoria4
# 15              categoria13
# 16               categoria5
# 17               categoria5
# 18               categoria4
# 19               categoria6
# 20               categoria3
# 21               categoria1
# 22              categoria11
# 23               categoria2
# 24               categoria4
# 25               categoria1
# 26               categoria2
# 27               categoria3
# 28               categoria3
# 29               categoria2
# 30               categoria1
# 31               categoria3
# ...

# %%
# 1. estimated_revenue_l365d_cat 

F1_index1 = df['estimated_revenue_l365d_cat'].value_counts().reset_index().set_index('estimated_revenue_l365d_cat')
F1_index1.plot(kind='bar', width=0.8, figsize=(10,4), color="red")
plt.title('Estimated Revenue L365d')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 2. review_scores_value_cat
F1_index2 = df['review_scores_value_cat'].value_counts().reset_index().set_index('review_scores_value_cat')
F1_index2["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Review Scores Value')
# Out:
# Text(0.5, 1.0, 'Review Scores Value')

# %%
# 3. calculated_host_listings_count_cat 
F1_index3 = df['calculated_host_listings_count_cat'].value_counts().reset_index().set_index('calculated_host_listings_count_cat')
F1_index3.plot(kind='area', figsize=(10,4), alpha=1)
plt.title('Calculated Host Listings Count')
# Out:
# Text(0.5, 1.0, 'Calculated Host Listings Count')

# %%
# 4. accommodates
F1_index4 = df['accommodates_cat'].value_counts().reset_index().set_index('accommodates_cat')
F1_index4.plot(kind='bar', width=0.8, figsize=(10,4), color="green")
plt.title('Accommodates')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 5. bathrooms_cat 
F1_index5 = df['bathrooms_cat'].value_counts().reset_index().set_index('bathrooms_cat')
F1_index5["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Bathrooms')
# Out:
# Text(0.5, 1.0, 'Bathrooms')

# %%
# 6. beds_cat
F1_index6 = df['beds_cat'].value_counts().reset_index().set_index('beds_cat')
F1_index6.plot(kind='area', figsize=(10,4), alpha=1)
plt.title('Beds')
# Out:
# Text(0.5, 1.0, 'Beds')

# %%
F1_index7 = df['price_cat'].value_counts().reset_index().set_index('price_cat')
F1_index7.plot(kind='bar', width=0.8, figsize=(10,4), color="blue")
plt.title('Price')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 8. maximum_nights_avg_
F1_index8 = df['maximum_nights_avg_ntm_cat'].value_counts().reset_index().set_index('maximum_nights_avg_ntm_cat')
F1_index8.plot(kind='area', figsize=(10,4), alpha=1)
plt.title('Maximum Nights Avg')
# Out:
# Text(0.5, 1.0, 'Maximum Nights Avg')

# %%
# 9. availability_365 
F1_index9 = df['availability_365_cat'].value_counts().reset_index().set_index('availability_365_cat')
F1_index9.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Availability 365')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
# 10. number_of_review
F1_index10 = df['number_of_reviews_cat'].value_counts().reset_index().set_index('number_of_reviews_cat')
F1_index10["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct='%0.1f%%')
plt.title('Number of Reviews')
# Out:
# Text(0.5, 1.0, 'Number of Reviews')
